# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime 
import matplotlib.dates as md
# Out:
# C:\Users\YOGESH\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv('pollution.csv')
df
# Out:
#            created_at  entry_id  Chadni Chowk  Gariahat  Dharmatala
# 0    26-10-2017 07:59    167601      2.562637  3.015531    2.758462
# 1    26-10-2017 08:00    167602      2.565861  3.016337    2.761685
# 2    26-10-2017 08:00    167603      2.569890  3.019560    2.764103
# 3    26-10-2017 08:01    167604      2.573114  3.019560    2.766520
# 4    26-10-2017 08:02    167605      2.576337  3.019560    2.768132
# ..                ...       ...           ...       ...         ...
# 495  26-10-2017 13:43    168096      2.565861  2.757656    2.565861
# 496  26-10-2017 13:43    168097      2.564249  2.756850    2.564249
# 497  26-10-2017 13:44    168098      2.579560  2.770549    2.579560
# 498  26-10-2017 13:45    168099      2.466740  2.670623    2.466740
# 499  26-10-2017 13:45    168100      2.537656  2.731868    2.537656
#
# [500 rows x 5 columns]

# %%
df.drop('entry_id',axis=1,inplace=True)
df
# Out:
#            created_at  Chadni Chowk  Gariahat  Dharmatala
# 0    26-10-2017 07:59      2.562637  3.015531    2.758462
# 1    26-10-2017 08:00      2.565861  3.016337    2.761685
# 2    26-10-2017 08:00      2.569890  3.019560    2.764103
# 3    26-10-2017 08:01      2.573114  3.019560    2.766520
# 4    26-10-2017 08:02      2.576337  3.019560    2.768132
# ..                ...           ...       ...         ...
# 495  26-10-2017 13:43      2.565861  2.757656    2.565861
# 496  26-10-2017 13:43      2.564249  2.756850    2.564249
# 497  26-10-2017 13:44      2.579560  2.770549    2.579560
# 498  26-10-2017 13:45      2.466740  2.670623    2.466740
# 499  26-10-2017 13:45      2.537656  2.731868    2.537656
#
# [500 rows x 4 columns]

# %%
max_value = df['Chadni Chowk'].max()
max_value
# Out:
# 3.023589744

# %%
 #finding out the time when max. pollution occurs at Chadni Chowk
    
df[df['Chadni Chowk']==3.023589744].drop(['Gariahat','Dharmatala'],axis=1)
# Out:
#            created_at  Chadni Chowk
# 297  26-10-2017 10:53       3.02359

# %%
max_value = df['Gariahat'].max()
max_value
# Out:
# 3.023589744

# %%
#finding out the time when max. pollution occurs at Gariahat

df[df['Gariahat']==3.023589744].drop(['Chadni Chowk','Dharmatala'],axis=1)
# Out:
#            created_at  Gariahat
# 97   26-10-2017 09:11   3.02359
# 397  26-10-2017 12:14   3.02359

# %%
max_value = df['Dharmatala'].max()
max_value
# Out:
# 3.023589744

# %%
#finding out the time when max. pollution occurs at Dharmatala

df[df['Dharmatala']==3.023589744].drop(['Chadni Chowk','Gariahat'],axis=1)
# Out:
#            created_at  Dharmatala
# 297  26-10-2017 10:53     3.02359

# %%
#finding out pollution level at Chadni Chowk by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':15})
x =pd.to_datetime(df['created_at'])
y=df['Chadni Chowk']
plt.plot_date(x, y)
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Chadni Chowk")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Chadni Chowk')

# %%
#finding out pollution level at Gariahat by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':15})
x =pd.to_datetime(df['created_at'])
y=df['Gariahat']
plt.plot_date(x, y,color='green')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Gariahat")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Gariahat')

# %%
#finding out pollution level at Dharmatala by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':15})
x =pd.to_datetime(df['created_at'])
y=df['Dharmatala']
plt.plot_date(x, y,color='red')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Dharmatala")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Dharmatala')

# %%
#pairplot
sns.pairplot(df,size=4)
# Out:
# C:\Users\YOGESH\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x="Chadni Chowk",y="Gariahat",data=df,color='green')

# %%
sns.jointplot(x="Chadni Chowk",y="Dharmatala",data=df,color='red')

# %%
sns.jointplot(x="Dharmatala",y="Gariahat",data=df,color='')
